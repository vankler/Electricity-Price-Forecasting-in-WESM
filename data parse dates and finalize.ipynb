# %%
 import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/Electricity Price Forecasting in WESM/data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# parse dates combine the Date and Interval columns creating Date_Interval
data = pd.read_csv(path + 'data_edited.csv', parse_dates=[[0, 1]])

# %%
data
# Out:
#        Date_Interval  Effective GWAP  Rolling Average
# 0         1/9/2015 0     1822.506078        10.848250
# 1         1/9/2015 1     1752.397260        21.279187
# 2         1/9/2015 2     1539.379580        30.442160
# 3         1/9/2015 3     1815.911913        41.251160
# 4         1/9/2015 4     2884.785234        58.422500
# ...              ...             ...              ...
# 56635  06/25/2021 19     4582.463868      6823.492048
# 56636  06/25/2021 20    13468.269470      6871.667956
# 56637  06/25/2021 21     8069.676643      6866.547378
# 56638  06/25/2021 22     3628.883036      6860.123532
# 56639  06/25/2021 23     2975.500891      6856.019752
#
# [56640 rows x 3 columns]

# %%
data.dtypes
# Out:
# Date_Interval       object
# Effective GWAP     float64
# Rolling Average    float64
# dtype: object

# %% [markdown]
# Since the `Date_Interval` column is still of type object, it must then be transformed into a datetime data type.

# %%
# Transform Date_Interval from object to datetime
data['Date_Interval'] = pd.to_datetime(data['Date_Interval'], format='%m/%d/%Y %H')

# %%
data.dtypes
# Out:
# Date_Interval      datetime64[ns]
# Effective GWAP            float64
# Rolling Average           float64
# dtype: object

# %%
# check to see if there's any null value
data.isnull().sum()
# Out:
# Date_Interval      0
# Effective GWAP     0
# Rolling Average    0
# dtype: int64

# %%
data.to_csv(path + 'wesm_dataset.csv', index=False)
